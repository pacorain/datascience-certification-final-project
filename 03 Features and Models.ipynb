# %% [markdown]
# # Clustering and Scoring Job Relocation Opportunities - Features and Models
# Austin Rainwater
#
# ---
#
# Now that I've obtained some data, I can extracting some features and building some models.

# %%
# !pip install --quiet --upgrade pymysql

import pandas as pd
import numpy as np

from sqlalchemy import (
    create_engine,
    MetaData,
    String,
    Integer,
    func as f,
    select
)
import yaml

with open('secrets.yaml', 'r') as secrets_file:
    secrets = yaml.safe_load(secrets_file)
    
conn_str = secrets['db_connection_string']
    
engine = create_engine(conn_str)
meta = MetaData()
meta.reflect(bind=engine)

# %% [markdown]
# ## Data
#
# Before I do anything, I need to grab the data. For now, I'm going to pull from the database into DataFrames, and then pickle the DataFrames.

# %%
try:
    cities = pd.read_pickle('data/cities.pkl')
except:
    cities = pd.read_sql(
        meta.tables['cities'].select(), 
        engine, 
        index_col='city_name'
    )
    cities.to_pickle('data/cities.pkl')
    
cities
# Out:
#                                                                       metro_name  \
# city_name
# 4S Ranch, California                                                   San Diego
# Aberdeen Township, New Jersey                       Freehold Borough, New Jersey
# Abington Township, Montgomery County, Pennsylvania                    Norristown
# Aboite Township, Allen County, Indiana                       Fort Wayne, Indiana
# Aboite, Indiana                                              Fort Wayne, Indiana
# ...                                                                          ...
# Zieglerville, Pennsylvania                                                Camden
# Zionhill, Pennsylvania                                                     Media
# Zorn, Texas                                                               Seguin
# Zuehl, Texas                                                              Seguin
# Zulu, Indiana                                                Fort Wayne, Indiana
#
#                                                       state_name  \
# city_name
# 4S Ranch, California                                  California
# Aberdeen Township, New Jersey                         New Jersey
# Abington Township, Montgomery County, Pennsylvania  Pennsylvania
# Aboite Township, Allen County, Indiana                   Indiana
# Aboite, Indiana                                          Indiana
# ...                                                          ...
# Zieglerville, Pennsylvania                          Pennsylvania
# Zionhill, Pennsylvania                              Pennsylvania
# Zorn, Texas                                                Texas
# Zuehl, Texas                                               Texas
# Zulu, Indiana                                            Indiana
#
#                                                     center_latitude  \
# city_name
# 4S Ranch, California                                      33.017500
# Aberdeen Township, New Jersey                             40.430068
# Abington Township, Montgomery County, Pennsylvania        40.100000
# Aboite Township, Allen County, Indiana                    41.052222
# Aboite, Indiana                                           41.000000
# ...                                                             ...
# Zieglerville, Pennsylvania                                40.276944
# Zionhill, Pennsylvania                                    40.484167
# Zorn, Texas                                               29.753056
# Zuehl, Texas                                              29.491667
# Zulu, Indiana                                             41.036944
#
#                                                     center_longitude  \
# city_name
# 4S Ranch, California                                     -117.111667
# Aberdeen Township, New Jersey                             -74.225075
# Abington Township, Montgomery County, Pennsylvania        -75.099722
# Aboite Township, Allen County, Indiana                    -85.285278
# Aboite, Indiana                                           -85.318056
# ...                                                              ...
# Zieglerville, Pennsylvania                                -75.480000
# Zionhill, Pennsylvania                                    -75.393889
# Zorn, Texas                                               -97.948056
# Zuehl, Texas                                              -98.152778
# Zulu, Indiana                                             -84.892222
#
#                                                     area_val  city_population  \
# city_name
# 4S Ranch, California                                     NaN              NaN
# Aberdeen Township, New Jersey                           7.77          19332.0
# Abington Township, Montgomery County, Pennsylvania     15.52          55557.0
# Aboite Township, Allen County, Indiana                 33.35              NaN
# Aboite, Indiana                                          NaN              NaN
# ...                                                      ...              ...
# Zieglerville, Pennsylvania                               NaN              NaN
# Zionhill, Pennsylvania                                   NaN              NaN
# Zorn, Texas                                              NaN              NaN
# Zuehl, Texas                                             NaN              NaN
# Zulu, Indiana                                            NaN              NaN
#
#                                                     population_density
# city_name
# 4S Ranch, California                                               NaN
# Aberdeen Township, New Jersey                                   3343.0
# Abington Township, Montgomery County, Pennsylvania                 NaN
# Aboite Township, Allen County, Indiana                          1073.2
# Aboite, Indiana                                                    NaN
# ...                                                                ...
# Zieglerville, Pennsylvania                                         NaN
# Zionhill, Pennsylvania                                             NaN
# Zorn, Texas                                                        NaN
# Zuehl, Texas                                                       NaN
# Zulu, Indiana                                                      NaN
#
# [3115 rows x 7 columns]

# %%
try:
    searches = pd.read_pickle('data/searches.pkl')
except:
    searches = pd.read_sql(
        meta.tables['city_foursquare_results'].select(), 
        engine
    )
    searches.to_pickle('data/searches.pkl')
    
searches
# Out:
#                          venue_id            search_city  search_radius  \
# 0        4b66def6f964a5202f2e2be3  Lyndhurst, New Jersey           1000
# 1        4b9a9f22f964a5201dc735e3  Lyndhurst, New Jersey           1000
# 2        4b44d7e7f964a520e6fd25e3  Lyndhurst, New Jersey           1000
# 3        4bbe1522c6a2ef3b8a43ddbd  Lyndhurst, New Jersey           1000
# 4        4bdb4c9a63c5c9b623432768  Lyndhurst, New Jersey           1000
# ...                           ...                    ...            ...
# 4513629  4bae5435f964a52068a33be3      York Center, Ohio         100000
# 4513630  4c372dda04cbb7131a42ee0d      York Center, Ohio         100000
# 4513631  4b91a65af964a520d6cc33e3      York Center, Ohio         100000
# 4513632  4dd6e9f652b1a5c6443fd34f      York Center, Ohio         100000
# 4513633  50898575e4b083f1927e88d9      York Center, Ohio         100000
#
#         query_type           query  search_popularity
# 0          section            food                  0
# 1          section            food                  1
# 2          section            food                  2
# 3          section            food                  3
# 4          section            food                  4
# ...            ...             ...                ...
# 4513629      query  ice cream shop                  9
# 4513630      query  ice cream shop                 10
# 4513631      query  ice cream shop                 11
# 4513632      query  ice cream shop                 12
# 4513633      query  ice cream shop                 13
#
# [4513634 rows x 6 columns]

# %%
try:
    venues = pd.read_pickle('data/venues.pkl')
except:
    venues = pd.read_sql(
        meta.tables['foursquare_venues'].select(),
        engine,
        index_col=['venue_id']
    )
    venues.to_pickle('data/venues.pkl')
    
venues
# Out:
#                                               venue_name  venue_location_lat  \
# venue_id
# 3fd66200f964a52000e71ee3                         Fat Cat           40.733665
# 3fd66200f964a52000f11ee3                    Melody Lanes           40.652726
# 3fd66200f964a52002ef1ee3                  The Short Stop           34.075293
# 3fd66200f964a52007f11ee3                     Poquito Mas           34.159801
# 3fd66200f964a52008e81ee3                   Serendipity 3           40.761758
# ...                                                  ...                 ...
# 600335afb50b926ccc98e77d             Cultura Coffee Shop           29.326754
# 600343989a58fc0b07106204               Redline Athletics           40.233030
# 6004a774cf4c6c1531cabe42  Haddonfield Zoo Sculpture Park           39.900356
# 6004b020c6f7954a4788243f                   Garnet Stream           39.919204
# 6004bd000f4eba3d9f7794ec                       Starbucks           32.988389
#
#                           venue_location_lng    venue_location_crossStreet  \
# venue_id
# 3fd66200f964a52000e71ee3          -74.002950  btwn 7th Ave S & Bleecker St
# 3fd66200f964a52000f11ee3          -74.002993                   at 5th Ave.
# 3fd66200f964a52002ef1ee3         -118.253701              at Sutherland St
# 3fd66200f964a52007f11ee3         -118.331202                  at Naomi St.
# 3fd66200f964a52008e81ee3          -73.965054            btwn 2nd & 3rd Ave
# ...                                      ...                           ...
# 600335afb50b926ccc98e77d          -98.551674                          None
# 600343989a58fc0b07106204          -75.225066                          None
# 6004a774cf4c6c1531cabe42          -75.027940                          None
# 6004b020c6f7954a4788243f          -75.361948                          None
# 6004bd000f4eba3d9f7794ec          -97.181412                          None
#
#                          venue_delivery_id venue_location_city  \
# venue_id
# 3fd66200f964a52000e71ee3              None            New York
# 3fd66200f964a52000f11ee3              None            Brooklyn
# 3fd66200f964a52002ef1ee3              None         Los Angeles
# 3fd66200f964a52007f11ee3              None             Burbank
# 3fd66200f964a52008e81ee3              None            New York
# ...                                    ...                 ...
# 600335afb50b926ccc98e77d              None         San Antonio
# 600343989a58fc0b07106204              None     Montgomeryville
# 6004a774cf4c6c1531cabe42              None         Haddonfield
# 6004b020c6f7954a4788243f              None         Springfield
# 6004bd000f4eba3d9f7794ec              None            Westlake
#
#                          venue_location_state            cat_level_1  \
# venue_id
# 3fd66200f964a52000e71ee3                   NY   Arts & Entertainment
# 3fd66200f964a52000f11ee3                   NY   Arts & Entertainment
# 3fd66200f964a52002ef1ee3                   CA              Nightlife
# 3fd66200f964a52007f11ee3                   CA                   Food
# 3fd66200f964a52008e81ee3                   NY                   Food
# ...                                       ...                    ...
# 600335afb50b926ccc98e77d                   TX                   Food
# 600343989a58fc0b07106204                   PA  Outdoors & Recreation
# 6004a774cf4c6c1531cabe42                   NJ  Outdoors & Recreation
# 6004b020c6f7954a4788243f                   PA  Outdoors & Recreation
# 6004bd000f4eba3d9f7794ec                   TX                   Food
#
#                                  cat_level_2 cat_level_3 cat_level_4
# venue_id
# 3fd66200f964a52000e71ee3         Music Venue   Jazz Club        None
# 3fd66200f964a52000f11ee3       Bowling Alley        None        None
# 3fd66200f964a52002ef1ee3                 Bar        None        None
# 3fd66200f964a52007f11ee3             Mexican        None        None
# 3fd66200f964a52008e81ee3            Desserts        None        None
# ...                                      ...         ...         ...
# 600335afb50b926ccc98e77d         Coffee Shop        None        None
# 600343989a58fc0b07106204  Athletics & Sports        None        None
# 6004a774cf4c6c1531cabe42                Park        None        None
# 6004b020c6f7954a4788243f                Park        None        None
# 6004bd000f4eba3d9f7794ec         Coffee Shop        None        None
#
# [228492 rows x 11 columns]

# %% [markdown]
# ## Control
#
# I have had lots of ideas for features using the data I've grabbed, and I'm not quite sure which ones would be the most effective, or what might be too much.
#
# So before I start developing features, I want to use the one-shot features I used in the TorontoSegementation notebook to cluster and score it. Then, I can re-run the model with new features to see how the scores have improved (or degraded).

# %%
search_city_venues = searches.join(venues, 'venue_id', how='inner')
search_city_venues['has_delivery'] = ~pd.isna(search_city_venues.venue_delivery_id)
search_city_venues = search_city_venues[search_city_venues.search_radius == 25000]
print(search_city_venues.shape)
search_city_venues.sample(1).T
# Out:
# (1682136, 18)
#                                                            1503510
# venue_id                                  4bbf3966006dc9b62b31fc3f
# search_city                                       McCook, Illinois
# search_radius                                                25000
# query_type                                                   query
# query                                                 hiking trail
# search_popularity                                               31
# venue_name                  Mile Marker Zero - Great Western Trail
# venue_location_lat                                         41.8896
# venue_location_lng                                        -87.9759
# venue_location_crossStreet                                    None
# venue_delivery_id                                             None
# venue_location_city                                     Villa Park
# venue_location_state                                            IL
# cat_level_1                                  Outdoors & Recreation
# cat_level_2                                                  Trail
# cat_level_3                                                   None
# cat_level_4                                                   None
# has_delivery                                                 False

# %%
categories = ['cat_level_1', 'cat_level_2', 'cat_level_3', 'cat_level_4']

byquery = pd.get_dummies(
    search_city_venues[['search_city', 'query'] + categories],
    columns=categories,
    prefix=['Category', 'Subcategory', 'Type 1', 'Type 2'],
    prefix_sep=': ',
    dtype=bool
).groupby(['search_city', 'query']).mean()

# %%
byquery
# Out:
#                                               Category: Arts & Entertainment  \
# search_city                   query
# Aberdeen Township, New Jersey arcade                                0.840000
#                               arts                                  1.000000
#                               bbq                                   0.000000
#                               british food                          0.000000
#                               coffee                                0.000000
# ...                                                                      ...
# Zionhill, Pennsylvania        hiking trail                          0.000000
#                               ice cream shop                        0.000000
#                               park                                  0.111111
#                               sights                                0.000000
#                               topPicks                              0.000000
#
#                                               Category: College & Education  \
# search_city                   query
# Aberdeen Township, New Jersey arcade                                    0.0
#                               arts                                      0.0
#                               bbq                                       0.0
#                               british food                              0.0
#                               coffee                                    0.0
# ...                                                                     ...
# Zionhill, Pennsylvania        hiking trail                              0.0
#                               ice cream shop                            0.0
#                               park                                      0.0
#                               sights                                    0.0
#                               topPicks                                  0.0
#
#                                               Category: Food  \
# search_city                   query
# Aberdeen Township, New Jersey arcade                    0.04
#                               arts                      0.00
#                               bbq                       0.92
#                               british food              0.45
#                               coffee                    0.88
# ...                                                      ...
# Zionhill, Pennsylvania        hiking trail              0.00
#                               ice cream shop            1.00
#                               park                      0.00
#                               sights                    1.00
#                               topPicks                  1.00
#
#                                               Category: Nightlife  \
# search_city                   query
# Aberdeen Township, New Jersey arcade                        0.000
#                               arts                          0.000
#                               bbq                           0.060
#                               british food                  0.025
#                               coffee                        0.000
# ...                                                           ...
# Zionhill, Pennsylvania        hiking trail                  0.000
#                               ice cream shop                0.000
#                               park                          0.000
#                               sights                        0.000
#                               topPicks                      0.000
#
#                                               Category: Outdoors & Recreation  \
# search_city                   query
# Aberdeen Township, New Jersey arcade                                 0.060000
#                               arts                                   0.000000
#                               bbq                                    0.000000
#                               british food                           0.150000
#                               coffee                                 0.000000
# ...                                                                       ...
# Zionhill, Pennsylvania        hiking trail                           1.000000
#                               ice cream shop                         0.000000
#                               park                                   0.888889
#                               sights                                 0.000000
#                               topPicks                               0.000000
#
#                                               Category: Professional  \
# search_city                   query
# Aberdeen Township, New Jersey arcade                           0.000
#                               arts                             0.000
#                               bbq                              0.000
#                               british food                     0.025
#                               coffee                           0.000
# ...                                                              ...
# Zionhill, Pennsylvania        hiking trail                     0.000
#                               ice cream shop                   0.000
#                               park                             0.000
#                               sights                           0.000
#                               topPicks                         0.000
#
#                                               Category: Residence  \
# search_city                   query
# Aberdeen Township, New Jersey arcade                          0.0
#                               arts                            0.0
#                               bbq                             0.0
#                               british food                    0.0
#                               coffee                          0.0
# ...                                                           ...
# Zionhill, Pennsylvania        hiking trail                    0.0
#                               ice cream shop                  0.0
#                               park                            0.0
#                               sights                          0.0
#                               topPicks                        0.0
#
#                                               Category: Shops  \
# search_city                   query
# Aberdeen Township, New Jersey arcade                    0.060
#                               arts                      0.000
#                               bbq                       0.020
#                               british food              0.225
#                               coffee                    0.120
# ...                                                       ...
# Zionhill, Pennsylvania        hiking trail              0.000
#                               ice cream shop            0.000
#                               park                      0.000
#                               sights                    0.000
#                               topPicks                  0.000
#
#                                               Category: Travel  \
# search_city                   query
# Aberdeen Township, New Jersey arcade                     0.000
#                               arts                       0.000
#                               bbq                        0.000
#                               british food               0.125
#                               coffee                     0.000
# ...                                                        ...
# Zionhill, Pennsylvania        hiking trail               0.000
#                               ice cream shop             0.000
#                               park                       0.000
#                               sights                     0.000
#                               topPicks                   0.000
#
#                                               Subcategory: ATM  ...  \
# search_city                   query                             ...
# Aberdeen Township, New Jersey arcade                       0.0  ...
#                               arts                         0.0  ...
#                               bbq                          0.0  ...
#                               british food                 0.0  ...
#                               coffee                       0.0  ...
# ...                                                        ...  ...
# Zionhill, Pennsylvania        hiking trail                 0.0  ...
#                               ice cream shop               0.0  ...
#                               park                         0.0  ...
#                               sights                       0.0  ...
#                               topPicks                     0.0  ...
#
#                                               Type 2: Ramen  \
# search_city                   query
# Aberdeen Township, New Jersey arcade                    0.0
#                               arts                      0.0
#                               bbq                       0.0
#                               british food              0.0
#                               coffee                    0.0
# ...                                                     ...
# Zionhill, Pennsylvania        hiking trail              0.0
#                               ice cream shop            0.0
#                               park                      0.0
#                               sights                    0.0
#                               topPicks                  0.0
#
#                                               Type 2: Shabu-Shabu  \
# search_city                   query
# Aberdeen Township, New Jersey arcade                          0.0
#                               arts                            0.0
#                               bbq                             0.0
#                               british food                    0.0
#                               coffee                          0.0
# ...                                                           ...
# Zionhill, Pennsylvania        hiking trail                    0.0
#                               ice cream shop                  0.0
#                               park                            0.0
#                               sights                          0.0
#                               topPicks                        0.0
#
#                                               Type 2: Shanghai  Type 2: Sushi  \
# search_city                   query
# Aberdeen Township, New Jersey arcade                       0.0            0.0
#                               arts                         0.0            0.0
#                               bbq                          0.0            0.0
#                               british food                 0.0            0.0
#                               coffee                       0.0            0.0
# ...                                                        ...            ...
# Zionhill, Pennsylvania        hiking trail                 0.0            0.0
#                               ice cream shop               0.0            0.0
#                               park                         0.0            0.0
#                               sights                       0.0            0.0
#                               topPicks                     0.0            0.0
#
#                                               Type 2: Szechuan  \
# search_city                   query
# Aberdeen Township, New Jersey arcade                       0.0
#                               arts                         0.0
#                               bbq                          0.0
#                               british food                 0.0
#                               coffee                       0.0
# ...                                                        ...
# Zionhill, Pennsylvania        hiking trail                 0.0
#                               ice cream shop               0.0
#                               park                         0.0
#                               sights                       0.0
#                               topPicks                     0.0
#
#                                               Type 2: Taiwanese  \
# search_city                   query
# Aberdeen Township, New Jersey arcade                        0.0
#                               arts                          0.0
#                               bbq                           0.0
#                               british food                  0.0
#                               coffee                        0.0
# ...                                                         ...
# Zionhill, Pennsylvania        hiking trail                  0.0
#                               ice cream shop                0.0
#                               park                          0.0
#                               sights                        0.0
#                               topPicks                      0.0
#
#                                               Type 2: Track  Type 2: Udon  \
# search_city                   query
# Aberdeen Township, New Jersey arcade                    0.0           0.0
#                               arts                      0.0           0.0
#                               bbq                       0.0           0.0
#                               british food              0.0           0.0
#                               coffee                    0.0           0.0
# ...                                                     ...           ...
# Zionhill, Pennsylvania        hiking trail              0.0           0.0
#                               ice cream shop            0.0           0.0
#                               park                      0.0           0.0
#                               sights                    0.0           0.0
#                               topPicks                  0.0           0.0
#
#                                               Type 2: Weight Loss Center  \
# search_city                   query
# Aberdeen Township, New Jersey arcade                                 0.0
#                               arts                                   0.0
#                               bbq                                    0.0
#                               british food                           0.0
#                               coffee                                 0.0
# ...                                                                  ...
# Zionhill, Pennsylvania        hiking trail                           0.0
#                               ice cream shop                         0.0
#                               park                                   0.0
#                               sights                                 0.0
#                               topPicks                               0.0
#
#                                               Type 2: Yoga Studio
# search_city                   query
# Aberdeen Township, New Jersey arcade                          0.0
#                               arts                            0.0
#                               bbq                             0.0
#                               british food                    0.0
#                               coffee                          0.0
# ...                                                           ...
# Zionhill, Pennsylvania        hiking trail                    0.0
#                               ice cream shop                  0.0
#                               park                            0.0
#                               sights                          0.0
#                               topPicks                        0.0
#
# [22974 rows x 441 columns]

# %%
by_query = pd.merge(
    search_city_venues[['venue_id', 'search_city', 'query']],
    cat_dummies,
    left_index=True,
    right_index=True
).groupby(
    ['search_city', 'query']
).mean()
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# /opt/conda/lib/python3.8/site-packages/pandas/core/groupby/generic.py in _cython_agg_blocks(self, how, alt, numeric_only, min_count)
#    1049             try:
# -> 1050                 result, _ = self.grouper.aggregate(
#    1051                     block.values, how, axis=1, min_count=min_count
#
# /opt/conda/lib/python3.8/site-packages/pandas/core/groupby/ops.py in aggregate(self, values, how, axis, min_count)
#     590     ) -> Tuple[np.ndarray, Optional[List[str]]]:
# --> 591         return self._cython_operation(
#     592             "aggregate", values, how, axis, min_count=min_count
#
# /opt/conda/lib/python3.8/site-packages/pandas/core/groupby/ops.py in _cython_operation(self, kind, values, how, axis, min_count, **kwargs)
#     470         if is_categorical_dtype(values.dtype) or is_sparse(values.dtype):
# --> 471             raise NotImplementedError(f"{values.dtype} dtype not supported")
#     472         elif is_datetime64_any_dtype(values.dtype):
#
# NotImplementedError: Sparse[int64, 0] dtype not supported
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-f1cfc92b98c9> in <module>
# ----> 1 features = pd.merge(
#       2     search_city_venues[['venue_id', 'search_city', 'search_radius', 'query']],
#       3     cat_dummies,
#       4     left_index=True,
#       5     right_index=True
#
# /opt/conda/lib/python3.8/site-packages/pandas/core/groupby/groupby.py in mean(self, numeric_only)
#    1393         Name: B, dtype: float64
#    1394         """
# -> 1395         return self._cython_agg_general(
#    1396             "mean",
#    1397             alt=lambda x, axis: Series(x).mean(numeric_only=numeric_only),
#
# /opt/conda/lib/python3.8/site-packages/pandas/core/groupby/generic.py in _cython_agg_general(self, how, alt, numeric_only, min_count)
#    1019         self, how: str, alt=None, numeric_only: bool = True, min_count: int = -1
#    1020     ) -> DataFrame:
# -> 1021         agg_blocks, agg_items = self._cython_agg_blocks(
#    1022             how, alt=alt, numeric_only=numeric_only, min_count=min_count
#    1023         )
#
# /opt/conda/lib/python3.8/site-packages/pandas/core/groupby/generic.py in _cython_agg_blocks(self, how, alt, numeric_only, min_count)
#    1076                 s = get_groupby(obj, self.grouper, observed=True)
#    1077                 try:
# -> 1078                     result = s.aggregate(lambda x: alt(x, axis=self.axis))
#    1079                 except TypeError:
#    1080                     # we may have an exception in trying to aggregate
#
# /opt/conda/lib/python3.8/site-packages/pandas/core/groupby/generic.py in aggregate(self, func, engine, engine_kwargs, *args, **kwargs)
#     253
#     254             if self.grouper.nkeys > 1:
# --> 255                 return self._python_agg_general(
#     256                     func, *args, engine=engine, engine_kwargs=engine_kwargs, **kwargs
#     257                 )
#
# /opt/conda/lib/python3.8/site-packages/pandas/core/groupby/groupby.py in _python_agg_general(self, func, engine, engine_kwargs, *args, **kwargs)
#    1083                 try:
#    1084                     # if this function is invalid for this dtype, we will ignore it.
# -> 1085                     result, counts = self.grouper.agg_series(obj, f)
#    1086                 except TypeError:
#    1087                     continue
#
# /opt/conda/lib/python3.8/site-packages/pandas/core/groupby/ops.py in agg_series(self, obj, func, engine, engine_kwargs, *args, **kwargs)
#     642             # In the datetime64tz case it would incorrectly cast to tz-naive
#     643             # TODO: can we get a performant workaround for EAs backed by ndarray?
# --> 644             return self._aggregate_series_pure_python(obj, func)
#     645
#     646         elif obj.index._has_complex_internals:
#
# /opt/conda/lib/python3.8/site-packages/pandas/core/groupby/ops.py in _aggregate_series_pure_python(self, obj, func, engine, engine_kwargs, *args, **kwargs)
#     699         splitter = get_splitter(obj, group_index, ngroups, axis=0)
#     700
# --> 701         for label, group in splitter:
#     702             if maybe_use_numba(engine):
#     703                 values, index = split_for_numba(group)
#
# /opt/conda/lib/python3.8/site-packages/pandas/core/groupby/ops.py in __iter__(self)
#     950
#     951         for i, (start, end) in enumerate(zip(starts, ends)):
# --> 952             yield i, self._chop(sdata, slice(start, end))
#     953
#     954     def _get_sorted_data(self) -> FrameOrSeries:
#
# /opt/conda/lib/python3.8/site-packages/pandas/core/groupby/ops.py in _chop(self, sdata, slice_obj)
#     962     def _chop(self, sdata: Series, slice_obj: slice) -> Series:
#     963         # fastpath equivalent to `sdata.iloc[slice_obj]`
# --> 964         mgr = sdata._mgr.get_slice(slice_obj)
#     965         # __finalize__ not called here, must be applied by caller if applicable
#     966         return sdata._constructor(mgr, name=sdata.name, fastpath=True)
#
# /opt/conda/lib/python3.8/site-packages/pandas/core/internals/managers.py in get_slice(self, slobj, axis)
#    1601
#    1602         blk = self._block
# -> 1603         array = blk._slice(slobj)
#    1604         block = blk.make_block_same_class(array, placement=slice(0, len(array)))
#    1605         return type(self)(block, self.index[slobj])
#
# /opt/conda/lib/python3.8/site-packages/pandas/core/internals/blocks.py in _slice(self, slicer)
#    1773                 )
#    1774
# -> 1775         return self.values[slicer]
#    1776
#    1777     def fillna(self, value, limit=None, inplace=False, downcast=None):
#
# /opt/conda/lib/python3.8/site-packages/pandas/core/arrays/sparse/array.py in __getitem__(self, key)
#     781             # TODO: this logic is surely elsewhere
#     782             # TODO: this could be more efficient
# --> 783             indices = np.arange(len(self), dtype=np.int32)[key]
#     784             return self.take(indices)
#     785         else:
#
# KeyboardInterrupt:

# %%
features
